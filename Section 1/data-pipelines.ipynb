# %%
import pandas as pd
import re

# %%
df = pd.read_csv('inputs/applications_dataset_1.csv')

# %%
df.head()
# Out:
#              name                              email date_of_birth mobile_no
# 0   William Dixon  William_Dixon@woodward-fuller.biz    1986/01/10  40601711
# 1    Kristen Horn               Kristen_Horn@lin.com    1974-09-10    737931
# 2  Kimberly Chang   Kimberly_Chang@johnson-lopez.biz    02/27/1974   2692047
# 3       Mary Ball              Mary_Ball@stevens.biz    02/05/1968    886359
# 4  Benjamin Craig           Benjamin_Craig@berry.net    12/11/1988    696429

# %%
# format mobile_no: check for only digits, length == 8
df['mobile_no'] = df['mobile_no'].apply(lambda x: ''.join(re.findall(r'\d+', x)))
df['still_successful'] = df['mobile_no'].apply(lambda x: True if len(x) == 8 else False)

# %%
# keep unsuccessful into another df
unsuccesful_df = df[~df['still_successful']].drop(columns='still_successful')
unsuccesful_df
# Out:
#                 name                             email date_of_birth mobile_no
# 1       Kristen Horn              Kristen_Horn@lin.com    1974-09-10    737931
# 2     Kimberly Chang  Kimberly_Chang@johnson-lopez.biz    02/27/1974   2692047
# 3          Mary Ball             Mary_Ball@stevens.biz    02/05/1968    886359
# 4     Benjamin Craig          Benjamin_Craig@berry.net    12/11/1988    696429
# 5       Cathy Werner         Cathy_Werner@martinez.net    2018-09-25   7138041
# ...              ...                               ...           ...       ...
# 1994   Sherry Martin    Sherry_Martin@cross-wright.org    1995/05/04     45471
# 1995       Robert Li               Robert_Li@brock.com    2018/11/07     38151
# 1996    Jesse Miller   Jesse_Miller@thompson-owens.biz    1961-03-06    854883
# 1997     Kevin Jones             Kevin_Jones@moore.org    26-01-1974    122217
# 1998    Rhonda Young           Rhonda_Young@knight.com    04-01-1958     53046
#
# [1503 rows x 4 columns]

# %%
# df retains still successful apps
df = df[df['still_successful']].drop(columns='still_successful')
df
# Out:
#                  name                                 email date_of_birth
# 0       William Dixon     William_Dixon@woodward-fuller.biz    1986/01/10  \
# 11          Scott Lee                Scott_Lee@phillips.com    2010-07-12
# 20        Patty Smith                  Patty_Smith@ross.com    27-08-1975
# 25        Travis Rice               Travis_Rice@bradley.net    05/08/2006
# 27     Sarah Jacobson     Sarah_Jacobson@mclean-jacobs.info    03/09/1958
# ...               ...                                   ...           ...
# 1965        Jody Reed          Jody_Reed@winters-taylor.biz    2015/12/30
# 1972    Susan Donovan     Susan_Donovan@jordan-anderson.com    30-01-1969
# 1974  Michael Serrano  Michael_Serrano@turner-maldonado.com    07/11/1982
# 1976   Michael Powell             Michael_Powell@mccall.com    1994/11/27
# 1978   Alexander Lowe             Alexander_Lowe@morris.com    1961/05/08
#
#      mobile_no
# 0     40601711
# 11    52145751
# 20    59428759
# 25    36316303
# 27    61071779
# ...        ...
# 1965  27588167
# 1972  85222335
# 1974  12792543
# 1976  63894311
# 1978  93074023
#
# [496 rows x 4 columns]

# %%
# format email: check for [alphanumerical]@[emailprovider].[com/net]
df[['first_email_part', 'second_email_part']] = df['email'].str.split('@', expand = True)
df[['emailprovider', 'com/net']] = df['second_email_part'].str.split('.', expand = True)
df['still_successful'] = df['com/net'].isin(['com', 'net'])

# %%
working_cols = ['first_email_part', 'second_email_part', 'emailprovider', 'com/net', 'still_successful']

# %%
# keep unsuccessful into another df
unsuccesful_df = pd.concat([unsuccesful_df, df[~df['still_successful']].drop(columns=working_cols)])
unsuccesful_df
# Out:
#                    name                             email date_of_birth
# 1          Kristen Horn              Kristen_Horn@lin.com    1974-09-10  \
# 2        Kimberly Chang  Kimberly_Chang@johnson-lopez.biz    02/27/1974
# 3             Mary Ball             Mary_Ball@stevens.biz    02/05/1968
# 4        Benjamin Craig          Benjamin_Craig@berry.net    12/11/1988
# 5          Cathy Werner         Cathy_Werner@martinez.net    2018-09-25
# ...                 ...                               ...           ...
# 1935  Henry Johnson Jr.          Henry_Johnson@horton.org    2012-05-15
# 1941          Joe Moody       Joe_Moody@johnson-watts.biz    1999-04-05
# 1950     Robert Cabrera            Robert_Cabrera@kim.org    1995-07-06
# 1958     Stephen Campos            Stephen_Campos@lam.biz    2005/01/23
# 1965          Jody Reed      Jody_Reed@winters-taylor.biz    2015/12/30
#
#      mobile_no
# 1       737931
# 2      2692047
# 3       886359
# 4       696429
# 5      7138041
# ...        ...
# 1935  54804439
# 1941  97781031
# 1950  99768879
# 1958  19488863
# 1965  27588167
#
# [1650 rows x 4 columns]

# %%
# df retains still successful apps
df = df[df['still_successful']].drop(columns=working_cols)
df
# Out:
#                   name                                 email date_of_birth
# 11           Scott Lee                Scott_Lee@phillips.com    2010-07-12  \
# 20         Patty Smith                  Patty_Smith@ross.com    27-08-1975
# 25         Travis Rice               Travis_Rice@bradley.net    05/08/2006
# 29       Sean Wang DDS         Sean_Wang@gibson-calderon.com    1960-03-11
# 30     Richard Estrada            Richard_Estrada@malone.com    1992/10/15
# ...                ...                                   ...           ...
# 1962  Daniel Armstrong            Daniel_Armstrong@brown.com    1982/07/14
# 1972     Susan Donovan     Susan_Donovan@jordan-anderson.com    30-01-1969
# 1974   Michael Serrano  Michael_Serrano@turner-maldonado.com    07/11/1982
# 1976    Michael Powell             Michael_Powell@mccall.com    1994/11/27
# 1978    Alexander Lowe             Alexander_Lowe@morris.com    1961/05/08
#
#      mobile_no
# 11    52145751
# 20    59428759
# 25    36316303
# 29    25595367
# 30    22821527
# ...        ...
# 1962  18991247
# 1972  85222335
# 1974  12792543
# 1976  63894311
# 1978  93074023
#
# [349 rows x 4 columns]

# %%
# format name: trim whitespaces, check for first name and last name separated by a space
df['name'] = df['name'].str.strip()
df['words_in_name'] = df['name'].apply(lambda x: len(x.split(' ')))
# df[['first_name', 'last_name']] = df['name'].str.split(' ', expand = True)

# %%
def clean_name(name):
  split_name = name.split(' ')
  if len(split_name) == 2:
    first_name, last_name = split_name
  elif len(split_name) > 2:
    # check for common salutations
    pass
  else:
    first_name, last_name = None, None

  return first_name, last_name

# %%
clean_name('Sean')
# Out:
# (None, None)

# %%
df[df['words_in_name'] > 2]
# Out:
#                            name                                email
# 29                Sean Wang DDS        Sean_Wang@gibson-calderon.com  \
# 93               Arthur Hall MD             Arthur_Hall@gonzalez.com
# 150         Dr. Samuel Thompson  Samuel_Thompson@sanchez-carroll.com
# 568        Rebecca Thompson DDS         Rebecca_Thompson@ferrell.biz
# 645            Mr. Daniel Smith            Daniel_Smith@cummings.com
# 758         Jennifer Martin PhD             Jennifer_Martin@mack.com
# 932            Arthur Gibson II  Arthur_Gibson@thompson-thompson.com
# 942   Miss Katherine Brennan MD         Katherine_Brennan@garcia.net
# 948         Charles Mendoza DVM            Charles_Mendoza@watts.org
# 1035           Mr. Bryan Porter             Bryan_Porter@elliott.com
# 1074              Janet Choi MD                  Janet_Choi@neal.com
# 1449          Miss Molly Miller          Molly_Miller@king-kelly.net
# 1467          Thomas Nelson DDS            Thomas_Nelson@brandt.info
# 1468          Robert Rivera DVM             Robert_Rivera@gibson.com
# 1469        Miss Michelle Lewis  Michelle_Lewis@wiggins-thornton.com
# 1479            Nicole Duffy MD   Nicole_Duffy@davenport-nelson.info
# 1666           Jacob Spencer MD          Jacob_Spencer@jefferson.net
# 1745             Karen Smith MD           Karen_Smith@washington.com
# 1811          Miss Lauren Solis       Lauren_Solis@frazier-lewis.com
# 1935          Henry Johnson Jr.             Henry_Johnson@horton.org
#
#      date_of_birth mobile_no  words_in_name
# 29      1960-03-11  25595367              3
# 93      03-11-1994  65493407              3
# 150     03-04-1984  99063183              3
# 568     20-07-1998  98761031              3
# 645     1986-03-08  26613823              3
# 758     2010/01/06  41092831              3
# 932     03-06-1961  75411807              3
# 942     11/13/1977  37918255              4
# 948     1952-11-09  56858727              3
# 1035    1957/02/14  88089671              3
# 1074    1986/07/18  66675695              3
# 1449    05-11-1977  99947663              3
# 1467    1993/10/02  12978607              3
# 1468    22-07-1950  35020847              3
# 1469    1983-01-21  64700455              3
# 1479    08-01-2009  18095111              3
# 1666    26-02-1962  41992359              3
# 1745    05/05/1963  91036383              3
# 1811    2014-09-22  13418359              3
# 1935    2012-05-15  54804439              3

# %%
df
# Out:
#                  name                                 email date_of_birth
# 0       William Dixon     William_Dixon@woodward-fuller.biz    1986/01/10  \
# 11          Scott Lee                Scott_Lee@phillips.com    2010-07-12
# 20        Patty Smith                  Patty_Smith@ross.com    27-08-1975
# 25        Travis Rice               Travis_Rice@bradley.net    05/08/2006
# 27     Sarah Jacobson     Sarah_Jacobson@mclean-jacobs.info    03/09/1958
# ...               ...                                   ...           ...
# 1965        Jody Reed          Jody_Reed@winters-taylor.biz    2015/12/30
# 1972    Susan Donovan     Susan_Donovan@jordan-anderson.com    30-01-1969
# 1974  Michael Serrano  Michael_Serrano@turner-maldonado.com    07/11/1982
# 1976   Michael Powell             Michael_Powell@mccall.com    1994/11/27
# 1978   Alexander Lowe             Alexander_Lowe@morris.com    1961/05/08
#
#      mobile_no first_email_part     second_email_part     emailprovider
# 0     40601711    William_Dixon   woodward-fuller.biz   woodward-fuller  \
# 11    52145751        Scott_Lee          phillips.com          phillips
# 20    59428759      Patty_Smith              ross.com              ross
# 25    36316303      Travis_Rice           bradley.net           bradley
# 27    61071779   Sarah_Jacobson    mclean-jacobs.info     mclean-jacobs
# ...        ...              ...                   ...               ...
# 1965  27588167        Jody_Reed    winters-taylor.biz    winters-taylor
# 1972  85222335    Susan_Donovan   jordan-anderson.com   jordan-anderson
# 1974  12792543  Michael_Serrano  turner-maldonado.com  turner-maldonado
# 1976  63894311   Michael_Powell            mccall.com            mccall
# 1978  93074023   Alexander_Lowe            morris.com            morris
#
#      com/net  still_successful
# 0        biz             False
# 11       com              True
# 20       com              True
# 25       net              True
# 27      info             False
# ...      ...               ...
# 1965     biz             False
# 1972     com              True
# 1974     com              True
# 1976     com              True
# 1978     com              True
#
# [496 rows x 9 columns]

# %%
pd.to_datetime(df['date_of_birth'], format='mixed')
# Out:
# 0     1986-01-10
# 1     2010-07-12
# 2     1975-08-27
# 3     2006-05-08
# 4     1958-03-09
#          ...
# 491   2015-12-30
# 492   1969-01-30
# 493   1982-07-11
# 494   1994-11-27
# 495   1961-05-08
# Name: date_of_birth, Length: 496, dtype: datetime64[ns]
