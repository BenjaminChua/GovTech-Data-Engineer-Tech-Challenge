# %%
import pandas as pd
import re
import numpy as np
import hashlib

# %%
ori_df = pd.read_csv('inputs/applications_dataset_2.csv')
df = ori_df.copy()

# %%
df.head()
# Out:
#               name                          email date_of_birth mobile_no
# 0    Tony Shepherd     Tony_Shepherd@petersen.com    07/03/2016    711447
# 1  Sherry Gonzalez   Sherry_Gonzalez@caldwell.biz    14-03-1973  66744895
# 2    Ashlee Austin     Ashlee_Austin@melendez.com    12/09/1992   6454197
# 3      David Brown  David_Brown@jackson-smith.biz    2001-09-22  69082983
# 4       Marc Meyer          Marc_Meyer@chavez.com    1996/05/17   9727376

# %%
df.shape
# Out:
# (3000, 4)

# %%
# format mobile_no: check for only digits, length == 8
df['mobile_no'] = df['mobile_no'].apply(lambda x: ''.join(re.findall(r'\d+', x)))
df['still_successful'] = df['mobile_no'].apply(lambda x: True if len(x) == 8 else False)

# %%
# keep unsuccessful into a list of indexes
unsuccessful_idx = df[~df['still_successful']].index
unsuccessful_idx
# Out:
# Index([   0,    2,    4,    7,   11,   12,   13,   15,   16,   17,
#        ...
#        2988, 2989, 2990, 2993, 2994, 2995, 2996, 2997, 2998, 2999],
#       dtype='int64', length=2255)

# %%
# df retains still successful apps
df = df[df['still_successful']].drop(columns='still_successful')
df
# Out:
#                     name                                   email
# 1        Sherry Gonzalez            Sherry_Gonzalez@caldwell.biz  \
# 3            David Brown           David_Brown@jackson-smith.biz
# 5          Jennifer Vega               Jennifer_Vega@jenkins.net
# 6           Denise Glass               Denise_Glass@calderon.org
# 8           Billy Knight                 Billy_Knight@thomas.biz
# ...                  ...                                     ...
# 2981         Marcus Sims                   Marcus_Sims@adams.com
# 2984      Angela Nichols      Angela_Nichols@manning-krueger.com
# 2986         Nicole Shea                 Nicole_Shea@mcclure.com
# 2991      Charles Clarke               Charles_Clarke@decker.com
# 2992  Alexander Hamilton  Alexander_Hamilton@allen-gillespie.org
#
#      date_of_birth mobile_no
# 1       14-03-1973  66744895
# 3       2001-09-22  69082983
# 5       03/07/1971  66551251
# 6       1982-05-31  77863943
# 8       01/27/1955  49833743
# ...            ...       ...
# 2981    2008-05-22  45883671
# 2984    03/15/2014  44151975
# 2986    1956-01-02  28795599
# 2991    2017/08/14  75379215
# 2992    1964/11/04  28127271
#
# [745 rows x 4 columns]

# %%
# format email: check for [alphanumerical]@[emailprovider].[com/net]
df[['first_email_part', 'second_email_part']] = df['email'].str.split('@', expand = True)
df[['emailprovider', 'com/net']] = df['second_email_part'].str.split('.', expand = True)
df['still_successful'] = df['com/net'].isin(['com', 'net'])

# %%
working_cols = ['first_email_part', 'second_email_part', 'emailprovider', 'com/net', 'still_successful']

# %%
# keep unsuccessful into a list of indexes
unsuccessful_idx = unsuccessful_idx.append(df[~df['still_successful']].index)
unsuccessful_idx
# Out:
# Index([   0,    2,    4,    7,   11,   12,   13,   15,   16,   17,
#        ...
#        2859, 2863, 2868, 2932, 2939, 2952, 2965, 2973, 2978, 2992],
#       dtype='int64', length=2476)

# %%
# df retains still successful apps
df = df[df['still_successful']].drop(columns=working_cols)
df
# Out:
#                     name                               email date_of_birth
# 5          Jennifer Vega           Jennifer_Vega@jenkins.net    03/07/1971  \
# 9            Shane Davis               Shane_Davis@smith.net    2006/06/25
# 10         Laura Harding           Laura_Harding@jackson.com    2017-12-18
# 21          Aaron Wilson       Aaron_Wilson@burke-benton.net    17-05-1987
# 29            Samuel Lee    Samuel_Lee@gardner-rodriguez.net    1974/09/02
# ...                  ...                                 ...           ...
# 2974  Kathleen Rodriguez  Kathleen_Rodriguez@frost-james.com    10/05/1967
# 2981         Marcus Sims               Marcus_Sims@adams.com    2008-05-22
# 2984      Angela Nichols  Angela_Nichols@manning-krueger.com    03/15/2014
# 2986         Nicole Shea             Nicole_Shea@mcclure.com    1956-01-02
# 2991      Charles Clarke           Charles_Clarke@decker.com    2017/08/14
#
#      mobile_no
# 5     66551251
# 9     42361783
# 10    32048503
# 21    75053391
# 29    57636831
# ...        ...
# 2974  65397891
# 2981  45883671
# 2984  44151975
# 2986  28795599
# 2991  75379215
#
# [524 rows x 4 columns]

# %%
# format name: trim whitespaces, check for first name and last name separated by a space
df['name'] = df['name'].str.strip()

# %%
def clean_name(name):
  split_name = name.split(' ')
  if len(split_name) == 2:
    first_name, last_name = split_name
  elif len(split_name) > 2:
    # check for salutations
    non_saluation_words = []
    for word in split_name:
      # word has more than 2 capital letters or contains .or is a known salutation
      if not (len(re.findall(r'[A-Z]', word)) >= 2 or '.' in word or word in ['Mr', 'Miss', 'Madam', 'Mdm', 'Jr']):
        non_saluation_words.append(word)
    if len(non_saluation_words) == 2:
      first_name, last_name = non_saluation_words
    else:
      first_name, last_name = None, None
  else:
    first_name, last_name = None, None

  return first_name, last_name

# %%
df[['first_name', 'last_name']] = df['name'].apply(clean_name).tolist()

# %%
# keep unsuccessful into a list of indexes
unsuccessful_idx = unsuccessful_idx.append(df[df['first_name'].isna() | df['last_name'].isna()].index)
unsuccessful_idx
# Out:
# Index([   0,    2,    4,    7,   11,   12,   13,   15,   16,   17,
#        ...
#        2859, 2863, 2868, 2932, 2939, 2952, 2965, 2973, 2978, 2992],
#       dtype='int64', length=2476)

# %%
# df retains still successful apps
df = df[~df['first_name'].isna() & ~df['last_name'].isna()]
df
# Out:
#                     name                               email date_of_birth
# 5          Jennifer Vega           Jennifer_Vega@jenkins.net    03/07/1971  \
# 9            Shane Davis               Shane_Davis@smith.net    2006/06/25
# 10         Laura Harding           Laura_Harding@jackson.com    2017-12-18
# 21          Aaron Wilson       Aaron_Wilson@burke-benton.net    17-05-1987
# 29            Samuel Lee    Samuel_Lee@gardner-rodriguez.net    1974/09/02
# ...                  ...                                 ...           ...
# 2974  Kathleen Rodriguez  Kathleen_Rodriguez@frost-james.com    10/05/1967
# 2981         Marcus Sims               Marcus_Sims@adams.com    2008-05-22
# 2984      Angela Nichols  Angela_Nichols@manning-krueger.com    03/15/2014
# 2986         Nicole Shea             Nicole_Shea@mcclure.com    1956-01-02
# 2991      Charles Clarke           Charles_Clarke@decker.com    2017/08/14
#
#      mobile_no first_name  last_name
# 5     66551251   Jennifer       Vega
# 9     42361783      Shane      Davis
# 10    32048503      Laura    Harding
# 21    75053391      Aaron     Wilson
# 29    57636831     Samuel        Lee
# ...        ...        ...        ...
# 2974  65397891   Kathleen  Rodriguez
# 2981  45883671     Marcus       Sims
# 2984  44151975     Angela    Nichols
# 2986  28795599     Nicole       Shea
# 2991  75379215    Charles     Clarke
#
# [524 rows x 6 columns]

# %%
# format DOB: Uses dayfirst for vague dates like 05/08/2006
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], format='mixed', dayfirst=True)

# %%
# calculate age and check if above 18
age_in_days = pd.to_datetime('01/01/2022', format='%d/%m/%Y', dayfirst=True) - df['date_of_birth']
age_in_years = np.floor(age_in_days / np.timedelta64(1, "Y"))
df['above_18'] = age_in_years.apply(lambda x: True if x >= 18 else False)

# %%
# convert DOB to string YYYYMMDD
df['date_of_birth'] = df['date_of_birth'].dt.strftime('%Y%m%d')

# %%
# keep unsuccessful into a list of indexes
unsuccessful_idx = unsuccessful_idx.append(df[~df['above_18']].index)
unsuccessful_idx
# Out:
# Index([   0,    2,    4,    7,   11,   12,   13,   15,   16,   17,
#        ...
#        2725, 2774, 2813, 2846, 2853, 2903, 2929, 2981, 2984, 2991],
#       dtype='int64', length=2588)

# %%
# df retains still successful apps
df = df[df['above_18']].reset_index(drop=True)
df
# Out:
#                    name                               email date_of_birth
# 0         Jennifer Vega           Jennifer_Vega@jenkins.net      19710703  \
# 1          Aaron Wilson       Aaron_Wilson@burke-benton.net      19870517
# 2            Samuel Lee    Samuel_Lee@gardner-rodriguez.net      19740902
# 3       Jennifer Weaver       Jennifer_Weaver@patterson.com      19781015
# 4    Mr. Timothy Ortega            Timothy_Ortega@ramos.com      19980401
# ..                  ...                                 ...           ...
# 407      Jeffrey Murray            Jeffrey_Murray@jones.net      19821221
# 408       Carla Jackson            Carla_Jackson@morris.com      19940715
# 409      Kristin Wagner          Kristin_Wagner@clayton.com      19970129
# 410  Kathleen Rodriguez  Kathleen_Rodriguez@frost-james.com      19670510
# 411         Nicole Shea             Nicole_Shea@mcclure.com      19560102
#
#     mobile_no first_name  last_name  above_18
# 0    66551251   Jennifer       Vega      True
# 1    75053391      Aaron     Wilson      True
# 2    57636831     Samuel        Lee      True
# 3    74152151   Jennifer     Weaver      True
# 4    59312963    Timothy     Ortega      True
# ..        ...        ...        ...       ...
# 407  27473887    Jeffrey     Murray      True
# 408  44275151      Carla    Jackson      True
# 409  66045343    Kristin     Wagner      True
# 410  65397891   Kathleen  Rodriguez      True
# 411  28795599     Nicole       Shea      True
#
# [412 rows x 7 columns]

# %%
# Validity checks are complete, generate Membership IDs
# Step 1: Hash birthday and truncate to first 5 digits
hashed_trunc_bdae = df['date_of_birth'].apply(lambda x: hashlib.sha256(x.encode('utf-8')).hexdigest()[:5])
# Step 2: Last name + _ + hash_trunc_bdae
df['membership_id'] = df['last_name'] + '_' + hashed_trunc_bdae
df
# Out:
#                    name                               email date_of_birth
# 0         Jennifer Vega           Jennifer_Vega@jenkins.net      19710703  \
# 1          Aaron Wilson       Aaron_Wilson@burke-benton.net      19870517
# 2            Samuel Lee    Samuel_Lee@gardner-rodriguez.net      19740902
# 3       Jennifer Weaver       Jennifer_Weaver@patterson.com      19781015
# 4    Mr. Timothy Ortega            Timothy_Ortega@ramos.com      19980401
# ..                  ...                                 ...           ...
# 407      Jeffrey Murray            Jeffrey_Murray@jones.net      19821221
# 408       Carla Jackson            Carla_Jackson@morris.com      19940715
# 409      Kristin Wagner          Kristin_Wagner@clayton.com      19970129
# 410  Kathleen Rodriguez  Kathleen_Rodriguez@frost-james.com      19670510
# 411         Nicole Shea             Nicole_Shea@mcclure.com      19560102
#
#     mobile_no first_name  last_name  above_18    membership_id
# 0    66551251   Jennifer       Vega      True       Vega_fc7cb
# 1    75053391      Aaron     Wilson      True     Wilson_6845c
# 2    57636831     Samuel        Lee      True        Lee_d3d5c
# 3    74152151   Jennifer     Weaver      True     Weaver_feb81
# 4    59312963    Timothy     Ortega      True     Ortega_dd4da
# ..        ...        ...        ...       ...              ...
# 407  27473887    Jeffrey     Murray      True     Murray_8d3f7
# 408  44275151      Carla    Jackson      True    Jackson_5ae26
# 409  66045343    Kristin     Wagner      True     Wagner_83f4e
# 410  65397891   Kathleen  Rodriguez      True  Rodriguez_2bb86
# 411  28795599     Nicole       Shea      True       Shea_abeb3
#
# [412 rows x 8 columns]

# %%
unsuccessful_df = ori_df.loc[unsuccessful_idx]
unsuccessful_df
# Out:
#                  name                               email date_of_birth
# 0       Tony Shepherd          Tony_Shepherd@petersen.com    07/03/2016  \
# 2       Ashlee Austin          Ashlee_Austin@melendez.com    12/09/1992
# 4          Marc Meyer               Marc_Meyer@chavez.com    1996/05/17
# 7     Emily Christian      Emily_Christian@hardy-ball.biz    1993/11/27
# 11      Zachary Payne         Zachary_Payne@espinoza.info    17-02-2018
# ...               ...                                 ...           ...
# 2903       Alex Baker                Alex_Baker@kelly.com    2012-04-23
# 2929     Kaylee Berry     Kaylee_Berry@walsh-mckenzie.com    2016-12-24
# 2981      Marcus Sims               Marcus_Sims@adams.com    2008-05-22
# 2984   Angela Nichols  Angela_Nichols@manning-krueger.com    03/15/2014
# 2991   Charles Clarke           Charles_Clarke@decker.com    2017/08/14
#
#       mobile_no
# 0        711447
# 2       6454197
# 4       9727376
# 7         83586
# 11      7802719
# ...         ...
# 2903   34292983
# 2929   74360527
# 2981   45883671
# 2984  4415 1975
# 2991   75379215
#
# [2588 rows x 4 columns]

# %%
# outputs
unsuccessful_df.to_csv('unsuccessful/unsuccessful_applicants.csv', index=False)
df.to_csv('successful/successful_applicants.csv', index=False)
